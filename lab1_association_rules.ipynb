# %% [markdown]
# <a href="https://colab.research.google.com/github/satkar605/association-rules/blob/main/lab1_association_rules.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LAB 1 : Association Rules

# %% [markdown]
# **How to install packages**

# %%
# !pip install numpy

# %% [markdown]
# ## import packages

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# ## load dataset

# %%
df = pd.read_csv('/content/drive/MyDrive/dsci-519-py-data/data/AmazonBinaryAll.csv')

# %% [markdown]
# ## generate frequent itemset

# %%
itemsets = apriori(df, min_support=0.4, use_colnames=True)

# %% [markdown]
# ## generate association rules

# %%
rules = association_rules(itemsets, metric="confidence", min_threshold=0.7)

# %% [markdown]
# ## sort association rules by lift

# %%
rules.sort_values(by=['lift'], ascending=False).head(6)
# Out:
#         antecedents      consequents  antecedent support  consequent support  \
# 9           (Paper)   (EBooks, Hard)               0.497               0.475
# 7    (EBooks, Hard)          (Paper)               0.475               0.497
# 6   (EBooks, Paper)           (Hard)               0.483               0.493
# 10           (Hard)  (EBooks, Paper)               0.493               0.483
# 5            (Hard)          (Paper)               0.493               0.497
# 4           (Paper)           (Hard)               0.497               0.493
#
#     support  confidence      lift  representativity  leverage  conviction  \
# 9     0.419    0.843058  1.774860               1.0  0.182925    3.345192
# 7     0.419    0.882105  1.774860               1.0  0.182925    4.266518
# 6     0.419    0.867495  1.759624               1.0  0.180881    3.826266
# 10    0.419    0.849899  1.759624               1.0  0.180881    3.444338
# ...

# %% [markdown]
# ## print rules

# %%
print(
    rules.sort_values(by=['lift'], ascending=False).head(6)
     .drop(columns=['antecedent support', 'consequent support', 'conviction'])
)
# Out:
#         antecedents      consequents  support  confidence      lift  \
# 9           (Paper)   (EBooks, Hard)    0.419    0.843058  1.774860
# 7    (EBooks, Hard)          (Paper)    0.419    0.882105  1.774860
# 6   (EBooks, Paper)           (Hard)    0.419    0.867495  1.759624
# 10           (Hard)  (EBooks, Paper)    0.419    0.849899  1.759624
# 5            (Hard)          (Paper)    0.426    0.864097  1.738626
# 4           (Paper)           (Hard)    0.426    0.857143  1.738626
#
#     representativity  leverage  zhangs_metric   jaccard  certainty  kulczynski
# 9                1.0  0.182925       0.867943  0.757685   0.701064    0.862582
# 7                1.0  0.182925       0.831572  0.757685   0.765617    0.862582
# 6                1.0  0.180881       0.835004  0.752244   0.738649    0.858697
# 10               1.0  0.180881       0.851473  0.752244   0.709668    0.858697
# 5                1.0  0.180979       0.837936  0.755319   0.729816    0.860620
# ...

# %%
itemsets.head()
# Out:
#    support         itemsets
# 0    0.629         (EBooks)
# 1    0.493           (Hard)
# 2    0.497          (Paper)
# 3    0.475   (EBooks, Hard)
# 4    0.483  (EBooks, Paper)
